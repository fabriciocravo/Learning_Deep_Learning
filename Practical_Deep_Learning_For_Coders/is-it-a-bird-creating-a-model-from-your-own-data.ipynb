# %% [markdown]
# ## Is it a bird?

# %%
#NB: Kaggle requires phone verification to use the internet or a GPU. If you haven't done that yet, the cell below will fail
#    This code is only here to check that your internet is enabled. It doesn't do anything else.
#    Here's a help thread on getting your phone number verified: https://www.kaggle.com/product-feedback/135367

import socket,warnings
try:
    socket.setdefaulttimeout(1)
    socket.socket(socket.AF_INET, socket.SOCK_STREAM).connect(('1.1.1.1', 53))
except socket.error as ex: raise Exception("STOP: No internet. Click '>|' in top right and set 'Internet' switch to on")

# %%
# It's a good idea to ensure you're running the latest version of any libraries you need.
# `!pip install -Uqq <libraries>` upgrades to the latest version of <libraries>
# NB: You can safely ignore any warnings or errors pip spits out about running as root or incompatibilities
import os
iskaggle = os.environ.get('KAGGLE_KERNEL_RUN_TYPE', '')

if iskaggle:
    # !pip install -Uqq fastai duckduckgo_search
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-io 0.21.0 requires tensorflow-io-gcs-filesystem==0.21.0, which is not installed.
# explainable-ai-sdk 1.3.2 requires xai-image-widget, which is not installed.
# dask-cudf 21.10.1 requires cupy-cuda114, which is not installed.
# beatrix-jupyterlab 3.1.6 requires google-cloud-bigquery-storage, which is not installed.
# tensorflow 2.6.2 requires numpy~=1.19.2, but you have numpy 1.20.3 which is incompatible.
# tensorflow 2.6.2 requires six~=1.15.0, but you have six 1.16.0 which is incompatible.
# tensorflow 2.6.2 requires typing-extensions~=3.7.4, but you have typing-extensions 3.10.0.2 which is incompatible.
# tensorflow 2.6.2 requires wrapt~=1.12.1, but you have wrapt 1.13.3 which is incompatible.
# tensorflow-transform 1.5.0 requires absl-py<0.13,>=0.9, but you have absl-py 0.15.0 which is incompatible.
# tensorflow-transform 1.5.0 requires numpy<1.20,>=1.16, but you have numpy 1.20.3 which is incompatible.
# tensorflow-transform 1.5.0 requires pyarrow<6,>=1, but you have pyarrow 6.0.1 which is incompatible.
# tensorflow-transform 1.5.0 requires tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,<2.8,>=1.15.2, but you have tensorflow 2.6.2 which is incompatible.
# tensorflow-serving-api 2.7.0 requires tensorflow<3,>=2.7.0, but you have tensorflow 2.6.2 which is incompatible.
# gcsfs 2021.11.1 requires fsspec==2021.11.1, but you have fsspec 2022.2.0 which is incompatible.
# flake8 4.0.1 requires importlib-metadata<4.3; python_version < "3.8", but you have importlib-metadata 4.11.3 which is incompatible.
# featuretools 1.6.0 requires numpy>=1.21.0, but you have numpy 1.20.3 which is incompatible.
# dask-cudf 21.10.1 requires dask==2021.09.1, but you have dask 2022.2.0 which is incompatible.
# dask-cudf 21.10.1 requires distributed==2021.09.1, but you have distributed 2022.2.0 which is incompatible.
# apache-beam 2.34.0 requires dill<0.3.2,>=0.3.1.1, but you have dill 0.3.4 which is incompatible.
# apache-beam 2.34.0 requires httplib2<0.20.0,>=0.8, but you have httplib2 0.20.2 which is incompatible.
# apache-beam 2.34.0 requires pyarrow<6.0.0,>=0.15.1, but you have pyarrow 6.0.1 which is incompatible.
# aioitertools 0.10.0 requires typing_extensions>=4.0; python_version < "3.10", but you have typing-extensions 3.10.0.2 which is incompatible.
# aiobotocore 2.1.2 requires botocore<1.23.25,>=1.23.24, but you have botocore 1.24.20 which is incompatible.

# %%
# Changed to execute pip for the entire fastai module

# !pip install fastai
# Out:
# Requirement already satisfied: fastai in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (2.7.14)
# Requirement already satisfied: torchvision>=0.11 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from fastai) (0.14.0)
# Requirement already satisfied: spacy<4 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from fastai) (3.7.3)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from fastai) (0.0.7)
# Requirement already satisfied: torch<2.3,>=1.10 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from fastai) (1.13.0)
# Requirement already satisfied: packaging in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from fastai) (20.9)
# Requirement already satisfied: pillow>=9.0.0 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from fastai) (10.2.0)
# Requirement already satisfied: fastprogress>=0.2.4 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from fastai) (1.0.3)
# Requirement already satisfied: scipy in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from fastai) (1.7.1)
# Requirement already satisfied: pip in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from fastai) (21.0.1)
# Requirement already satisfied: requests in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from fastai) (2.25.1)
# Requirement already satisfied: pyyaml in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from fastai) (5.4.1)
# Requirement already satisfied: matplotlib in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from fastai) (3.3.4)
# Requirement already satisfied: scikit-learn in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from fastai) (0.24.1)
# Requirement already satisfied: fastcore<1.6,>=1.5.29 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from fastai) (1.5.29)
# Requirement already satisfied: pandas in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from fastai) (1.2.4)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (2.0.10)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (3.3.0)
# Requirement already satisfied: numpy>=1.15.0 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (1.20.1)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (0.9.0)
# Requirement already satisfied: jinja2 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (2.11.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (3.0.12)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (8.2.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (1.1.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (3.0.9)
# Requirement already satisfied: setuptools in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (52.0.0.post20210125)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (1.0.5)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (0.3.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (1.0.10)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (2.6.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (4.59.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (6.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (2.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from spacy<4->fastai) (2.4.8)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from packaging->fastai) (2.4.7)
# Requirement already satisfied: pydantic-core==2.16.2 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai) (2.16.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai) (4.9.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai) (0.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from requests->fastai) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from requests->fastai) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from requests->fastai) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from requests->fastai) (4.0.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from thinc<8.3.0,>=8.2.2->spacy<4->fastai) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from thinc<8.3.0,>=8.2.2->spacy<4->fastai) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from typer<0.10.0,>=0.3.0->spacy<4->fastai) (7.1.2)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from weasel<0.4.0,>=0.1.0->spacy<4->fastai) (0.16.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from jinja2->spacy<4->fastai) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->fastai) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->fastai) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->fastai) (2.8.1)
# Requirement already satisfied: six in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from cycler>=0.10->matplotlib->fastai) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from pandas->fastai) (2021.1)
# Requirement already satisfied: joblib>=0.11 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->fastai) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->fastai) (2.1.0)

# %%
# !pip install duckduckgo_search
# Out:
# Requirement already satisfied: duckduckgo_search in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (4.4)
# Requirement already satisfied: click>=8.1.7 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from duckduckgo_search) (8.1.7)
# Requirement already satisfied: docstring-inheritance>=2.1.2 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from duckduckgo_search) (2.1.2)
# Requirement already satisfied: curl-cffi>=0.6.0b7 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from duckduckgo_search) (0.6.0b9)
# Requirement already satisfied: lxml>=4.9.3 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from duckduckgo_search) (5.1.0)
# Requirement already satisfied: nest-asyncio>=1.6.0 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from duckduckgo_search) (1.6.0)
# Requirement already satisfied: certifi in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from curl-cffi>=0.6.0b7->duckduckgo_search) (2020.12.5)
# Requirement already satisfied: cffi>=1.12.0 in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from curl-cffi>=0.6.0b7->duckduckgo_search) (1.14.5)
# Requirement already satisfied: pycparser in /Users/fabriciocravo/opt/anaconda3/lib/python3.8/site-packages (from cffi>=1.12.0->curl-cffi>=0.6.0b7->duckduckgo_search) (2.20)

# %% [markdown]
# In 2015 the idea of creating a computer system that could recognise birds was considered so outrageously challenging that it was the basis of [this XKCD joke](https://xkcd.com/1425/):

# %% [markdown]
# ![image.png](attachment:a0483178-c30e-4fdd-b2c2-349e130ab260.png)

# %% [markdown]
# But today, we can do exactly that, in just a few minutes, using entirely free resources!
#
# The basic steps we'll take are:
#
# 1. Use DuckDuckGo to search for images of "bird photos"
# 1. Use DuckDuckGo to search for images of "forest photos"
# 1. Fine-tune a pretrained neural network to recognise these two groups
# 1. Try running this model on a picture of a bird and see if it works.

# %% [markdown]
# ## Step 1: Download images of birds and non-birds

# %%
from duckduckgo_search import DDGS
from fastcore.all import *

# %%
def search_images(term, max_images=30):
    print(f"Searching for '{term}'")
    with DDGS() as ddgs:
        return L(ddgs.images(term, max_results=max_images)).itemgot('image')

# %% [markdown]
# Let's start by searching for a bird photo and seeing what kind of result we get. We'll start by getting URLs from a search:

# %%
#NB: `search_images` depends on duckduckgo.com, which doesn't always return correct responses.
#    If you get a JSON error, just try running it again (it may take a couple of tries).
urls = search_images('bird photos', max_images=10)
urls[0]
# Out:
# Searching for 'bird photos'
# <ipython-input-21-20ccfc18625f>:3: UserWarning: DDGS running in an async loop. This may cause errors. Use AsyncDDGS instead.
#   with DDGS() as ddgs:
# 'https://images.pexels.com/photos/1661179/pexels-photo-1661179.jpeg?cs=srgb&dl=green-bird-1661179.jpg&fm=jpg'

# %%
print(urls)
# Out:
# ['https://images.pexels.com/photos/1661179/pexels-photo-1661179.jpeg?cs=srgb&dl=green-bird-1661179.jpg&fm=jpg', 'https://images.pexels.com/photos/326900/pexels-photo-326900.jpeg?cs=srgb&dl=wood-flight-bird-326900.jpg&fm=jpg', 'http://www.voidphase.com/media/2010/12/bird_gouldian_finch_1920.jpg', 'https://upload.wikimedia.org/wikipedia/commons/6/67/Mockingbird,_Northern_SunsetBeach.jpg', 'https://i.redd.it/n1e0kjh3nwu21.jpg', 'https://blog.nationalgeographic.org/wp-content/uploads/2012/08/Lennart-Hessel.jpg', 'https://photographylife.com/wp-content/uploads/2022/01/LVP0594-NEF_DxO_DeepPRIME-1.jpg', 'https://images.alphacoders.com/492/492674.jpg', 'http://upload.wikimedia.org/wikipedia/commons/9/9b/Eastern_Bluebird-27527-2.jpg', 'https://static.pexels.com/photos/97533/pexels-photo-97533.jpeg']

# %% [markdown]
# ...and then download a URL and take a look at it:

# %%
from fastdownload import download_url
dest = 'bird.jpg'
download_url(urls[0], dest, show_progress=False)

from fastai.vision.all import *
im = Image.open(dest)
im.to_thumb(256,256)
# Out:
# <PIL.Image.Image image mode=RGB size=219x256>

# %% [markdown]
# Now let's do the same with "forest photos":

# %%
download_url(search_images('forest photos', max_images=1)[0], 'forest.jpg', show_progress=False)
Image.open('forest.jpg').to_thumb(256,256)
# Out:
# Searching for 'forest photos'
# <ipython-input-21-20ccfc18625f>:3: UserWarning: DDGS running in an async loop. This may cause errors. Use AsyncDDGS instead.
#   with DDGS() as ddgs:
# <PIL.Image.Image image mode=RGB size=256x170>

# %% [markdown]
# Our searches seem to be giving reasonable results, so let's grab a few examples of each of "bird" and "forest" photos, and save each group of photos to a different folder (I'm also trying to grab a range of lighting conditions here):

# %%
searches = 'forest','bird'
path = Path('bird_or_not')
from time import sleep

for o in searches:
    dest = (path/o)
    dest.mkdir(exist_ok=True, parents=True)
    download_images(dest, urls=search_images(f'{o} photo'))
    sleep(10)  # Pause between searches to avoid over-loading server
    download_images(dest, urls=search_images(f'{o} sun photo'))
    sleep(10)
    download_images(dest, urls=search_images(f'{o} shade photo'))
    sleep(10)
    resize_images(path/o, max_size=400, dest=path/o)
# Out:
# Searching for 'forest photo'
# <ipython-input-21-20ccfc18625f>:3: UserWarning: DDGS running in an async loop. This may cause errors. Use AsyncDDGS instead.
#   with DDGS() as ddgs:
# Searching for 'forest sun photo'
# Searching for 'forest shade photo'
# Searching for 'bird photo'
# Searching for 'bird sun photo'
# Searching for 'bird shade photo'

# %% [markdown]
# ## Step 2: Train our model

# %% [markdown]
# Some photos might not download correctly which could cause our model training to fail, so we'll remove them:

# %%
failed = verify_images(get_image_files(path))
failed.map(Path.unlink)
len(failed)
# Out:
# 3

# %% [markdown]
# To train a model, we'll need `DataLoaders`, which is an object that contains a *training set* (the images used to create a model) and a *validation set* (the images used to check the accuracy of a model -- not used during training). In `fastai` we can create that easily using a `DataBlock`, and view sample images from it:

# %%
# Define the device
device = torch.device('cpu')
defaults.device = torch.device('cpu')

dls = DataBlock(
    blocks=(ImageBlock, CategoryBlock), 
    get_items=get_image_files, 
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=[Resize(192, method='squish')]
).dataloaders(path, bs=32, device=device)

dls.show_batch(max_n=6)

# %% [markdown]
# Here what each of the `DataBlock` parameters means:
#
#     blocks=(ImageBlock, CategoryBlock),
#
# The inputs to our model are images, and the outputs are categories (in this case, "bird" or "forest").
#
#     get_items=get_image_files,
#
# To find all the inputs to our model, run the `get_image_files` function (which returns a list of all image files in a path).
#
#     splitter=RandomSplitter(valid_pct=0.2, seed=42),
#
# Split the data into training and validation sets randomly, using 20% of the data for the validation set.
#
#     get_y=parent_label,
#
# The labels (`y` values) is the name of the `parent` of each file (i.e. the name of the folder they're in, which will be *bird* or *forest*).
#
#     item_tfms=[Resize(192, method='squish')]
#
# Before training, resize each image to 192x192 pixels by "squishing" it (as opposed to cropping it).

# %% [markdown]
# Now we're ready to train our model. The fastest widely used computer vision model is `resnet18`. You can train this in a few minutes, even on a CPU! (On a GPU, it generally takes under 10 seconds...)
#
# `fastai` comes with a helpful `fine_tune()` method which automatically uses best practices for fine tuning a pre-trained model, so we'll use that.

# %%
learn = vision_learner(dls, resnet18, metrics=error_rate, device=device)
learn.model = learn.model.cpu()
learn.fine_tune(3)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-49-fbd179f27f7d> in <module>
# ----> 1 learn = vision_learner(dls, resnet18, metrics=error_rate, device=device)
#       2 learn.model = learn.model.cpu()
#       3 learn.fine_tune(3)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/fastai/vision/learner.py in vision_learner(dls, arch, normalize, n_out, pretrained, weights, loss_func, opt_func, lr, splitter, cbs, metrics, path, model_dir, wd, wd_bn_bias, train_bn, moms, cut, init, custom_head, concat_pool, pool, lin_ftrs, ps, first_bn, bn_final, lin_first, y_range, **kwargs)
#     233         if normalize: _timm_norm(dls, cfg, pretrained, n_in)
#     234     else:
# --> 235         if normalize: _add_norm(dls, meta, pretrained, n_in)
#     236         model = create_vision_model(arch, n_out, pretrained=pretrained, weights=weights, **model_args)
#     237
#
# ~/opt/anaconda3/lib/python3.8/site-packages/fastai/vision/learner.py in _add_norm(dls, meta, pretrained, n_in)
#     203     if n_in != len(stats[0]): return
#     204     if not dls.after_batch.fs.filter(risinstance(Normalize)):
# --> 205         dls.add_tfms([Normalize.from_stats(*stats)],'after_batch')
#     206
#     207 # %% ../../nbs/21_vision.learner.ipynb 41
#
# ~/opt/anaconda3/lib/python3.8/site-packages/fastai/data/transforms.py in from_stats(cls, mean, std, dim, ndim, cuda)
#     368
#     369     @classmethod
# --> 370     def from_stats(cls, mean, std, dim=1, ndim=4, cuda=True): return cls(*broadcast_vec(dim, ndim, mean, std, cuda=cuda))
#     371
#     372     def setups(self, dl:DataLoader):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/fastai/data/transforms.py in broadcast_vec(dim, ndim, cuda, *t)
#     358     v[dim] = -1
#     359     f = to_device if cuda else noop
# --> 360     return [f(tensor(o).view(*v)) for o in t]
#     361
#     362 # %% ../../nbs/05_data.transforms.ipynb 115
#
# ~/opt/anaconda3/lib/python3.8/site-packages/fastai/data/transforms.py in <listcomp>(.0)
#     358     v[dim] = -1
#     359     f = to_device if cuda else noop
# --> 360     return [f(tensor(o).view(*v)) for o in t]
#     361
#     362 # %% ../../nbs/05_data.transforms.ipynb 115
#
# ~/opt/anaconda3/lib/python3.8/site-packages/fastai/torch_core.py in to_device(b, device, non_blocking)
#     283         if isinstance(o,Tensor): return o.to(device, non_blocking=non_blocking)
#     284         return o
# --> 285     return apply(_inner, b)
#     286
#     287 # %% ../nbs/00_torch_core.ipynb 76
#
# ~/opt/anaconda3/lib/python3.8/site-packages/fastai/torch_core.py in apply(func, x, *args, **kwargs)
#     222     if is_listy(x): return type(x)([apply(func, o, *args, **kwargs) for o in x])
#     223     if isinstance(x,(dict,MutableMapping)): return {k: apply(func, v, *args, **kwargs) for k,v in x.items()}
# --> 224     res = func(x, *args, **kwargs)
#     225     return res if x is None else retain_type(res, x)
#     226
#
# ~/opt/anaconda3/lib/python3.8/site-packages/fastai/torch_core.py in _inner(o)
#     281     def _inner(o):
#     282         # ToDo: add TensorDict when released
# --> 283         if isinstance(o,Tensor): return o.to(device, non_blocking=non_blocking)
#     284         return o
#     285     return apply(_inner, b)
#
# RuntimeError: The MPS backend is supported on MacOS 12.3+.Current OS version can be queried using `sw_vers`

# %% [markdown]
# Generally when I run this I see 100% accuracy on the validation set (although it might vary a bit from run to run).
#
# "Fine-tuning" a model means that we're starting with a model someone else has trained using some other dataset (called the *pretrained model*), and adjusting the weights a little bit so that the model learns to recognise your particular dataset. In this case, the pretrained model was trained to recognise photos in *imagenet*, and widely-used computer vision dataset with images covering 1000 categories) For details on fine-tuning and why it's important, check out the [free fast.ai course](https://course.fast.ai/).

# %% [markdown]
# ## Step 3: Use our model (and build your own!)

# %% [markdown]
# Let's see what our model thinks about that bird we downloaded at the start:

# %%
is_bird,_,probs = learn.predict(PILImage.create('bird.jpg'))
print(f"This is a: {is_bird}.")
print(f"Probability it's a bird: {probs[0]:.4f}")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# This is a: bird.
# Probability it's a bird: 1.0000

# %% [markdown]
# Good job, resnet18. :)
#
# So, as you see, in the space of a few years, creating computer vision classification models has gone from "so hard it's a joke" to "trivially easy and free"!
#
# It's not just in computer vision. Thanks to deep learning, computers can now do many things which seemed impossible just a few years ago, including [creating amazing artworks](https://openai.com/dall-e-2/), and [explaining jokes](https://www.datanami.com/2022/04/22/googles-massive-new-language-model-can-explain-jokes/). It's moving so fast that even experts in the field have trouble predicting how it's going to impact society in the coming years.
#
# One thing is clear -- it's important that we all do our best to understand this technology, because otherwise we'll get left behind!

# %% [markdown]
# Now it's your turn. Click "Copy & Edit" and try creating your own image classifier using your own image searches!
#
# If you enjoyed this, please consider clicking the "upvote" button in the top-right -- it's very encouraging to us notebook authors to know when people appreciate our work.
